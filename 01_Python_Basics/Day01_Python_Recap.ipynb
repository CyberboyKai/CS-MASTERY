# %% [markdown]
# Object: In Python, everything is object. It is a data memorized in a memory.
# For example, if Python was a movie, every characters are object.
# Data type: A data type is a classification that defines the values an object can hold and the operations it can perform

# %%
# int data type
type(123)
# Out:
# int

# %%
#float data type

type(1.2)
# Out:
# float

# %%
#str data type
type("Hello world")
# Out:
# str

# %%
#input function

input()
# Out:
# 'Kai'

# %%
name = input("what's your name?")
print("Hello", "Mr", name)
# Out:
# Hello Mr Kai

# %%
# I/O function
input()
# Out:
# 'Kwanwoo Lee'

# %%
i = 1
if i < 1:
    print("more than 1")
else: 
    print("less or equal to 1")
# Out:
# less or equal to 1

# %% [markdown]
# Numeric Types
# int: 정수 integer
# float: 실수 real
# complex: 복소수 complex 1.0 + 2.0j

# %%
#자료형 이름 확인
type(1323)

# %%
# 숫자 리터럴 사이에 언더스코어(_)를 삽입하면 무시합니다.
c = 1_000_000

# %%
# 복소수 complex
1+2j
# Out:
# (1+2j)

# %%
type(1+2j)
# Out:
# complex

# %%
type(complex(1,2))
# Out:
# complex

# %%
complex(1,2) - complex(3,5)
# Out:
# (-2-3j)

# %%
complex(1,2) + 2
# Out:
# (3+2j)

# %% [markdown]
# Variables
# 대입연산자 Assignment operators

# %%
a = 7
b = 3
c = a + b
print(c)
# Out:
# 10

# %%
# 정의되지않은 변수는 사용못함
print(d) # d has not been defined yet.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # 정의되지않은 변수는 사용못함
# ----> 2 print(d) # d has not been defined yet.
#
# NameError: name 'd' is not defined

# %%
#여러 변수 동시에 정의할 수 있음
